# %%
import sys
import logging
import time
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedShuffleSplit

from xgboost import XGBClassifier

import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from keras.regularizers import l1_l2
# Out:
# Using TensorFlow backend.

# %%
def elapsed_time(start_time, end_time):
    elapsed_sec = end_time - start_time
    h = int(elapsed_sec / (60 * 60))
    m = int((elapsed_sec % (60 * 60)) / 60)
    s = int(elapsed_sec % 60)
    return "{}:{:>02}:{:>02}".format(h, m, s)


def standarize_feature(train_df, test_df, cols):
    scaler = StandardScaler()
    for col in cols:
        train_df[col] = scaler.fit_transform(train_df[col].reshape(-1,1).astype(np.float32))
        test_df[col] = scaler.transform(test_df[col].reshape(-1,1).astype(np.float32))
    return None


def extend_bounds(bins):
    bins[0] = bins[0] - 1
    bins[-1] = bins[-1] + 1

# %%
def load_data(train_data_path='UCL course/Applied ML/otto/input_data/train.csv', test_data_path = 'UCL course/Applied ML/otto/input_data/test.csv'):
    train_df = pd.read_csv(train_data_path, sep=',', index_col=0, header=0)
    test_df = pd.read_csv(test_data_path, sep=',', index_col=0, header=0)
    
    train_df['target'] = train_df['target'].str[-1].astype(int) - 1
        
    return train_df, test_df

# %%
def process_data(train_df, test_df, ylabel='target', standarization=False, transform=None):
    numerical_features = train_df.columns

    if standarization:
        standarized_features = numerical_features
        standarize_feature(train_df, test_df, standarized_features)
    
    X = train_df.drop(ylabel, axis=1).values
    y = train_df[ylabel].values
    X_submission = test_df.values
    
    if transform == 'log':
        X = np.log(X+1)
        X_submission = np.log(X_submission+1)
        scaler = StandardScaler()
        scaler.fit(X)
        X = scaler.transform(X)
        X_submission = scaler.transform(X_submission)
    elif transform == 'sqrt':
        X = np.sqrt(X + 3.0 / 8)
        X_submission = np.sqrt(X_submission + 3.0 / 8)
    elif transform == 'pca':
        pca = PCA(n_components=3).fit(X)
        X = pca.transform(X)
        X_submission = pca.transform(X_submission)
    elif transform == 'tsne':
        tsne = TSNE(n_components=3).fit(X)
        X = tsne.transform(X)
        X_submission = tsne.transform(X_submission)
    elif transform == 'pca+':
        pca = PCA(n_components=3).fit(X)
        X = np.hstack((X, pca.transform(X)))
        X_submission = np.hstack((X, pca.transform(X)))
    elif transform == 'tsne+':
        tsne = TSNE(n_components=3).fit(X)
        X = np.hstack((X, tsne.transform(X)))
        X_submission = np.hstack((X_submission, tsne.transform(X_submission)))        
    return X, y, X_submission

# %%
def evaluate(y, y_pred):
    logloss = log_loss(y, y_pred)
    return logloss

# %%
def models_Split_train(models, X, y, X_submission, n_classes, n_folds=5):
  sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
  for train_index, test_index in sss.split(X, y):
      X_train = X[train_index]
      X_val = X[test_index]

      y_train = y[train_index]
      y_val = y[test_index]
  for i, model in enumerate(models):
    print ("Model %d:" % i, model)   
    avg_logloss = 0
    model.fit(X_train, y_train)
    y_test_pred = model.predict_proba(X_val)
    logloss = evaluate(y_val, y_test_pred)
    print ("  logloss: %f" % logloss)
  return logloss

# %%
def models_CV_train(models, X, y, X_submission, n_classes, n_folds=5):
    summary = {}

    skf = list(StratifiedKFold(n_folds,shuffle=True, random_state=0).split(X, y))
    
    stack_train = np.zeros((X.shape[0], n_classes, len(models)))
    stack_test = np.zeros((X_submission.shape[0], n_classes, len(models)))
    
    for i, model in enumerate(models):
        print ("Model %d:" % i, model)
        
        avg_logloss = 0
        
        stack_test_model_i = np.zeros((X_submission.shape[0], n_classes, len(skf)))
        for j, (train_idx, test_idx) in enumerate(skf):
            print ("  Fold %d" % j)
            X_train = X[train_idx]
            y_train = y[train_idx]
            X_test = X[test_idx]
            y_test = y[test_idx]

            model.fit(X_train, y_train)
            
            y_test_pred = model.predict_proba(X_test)          
            stack_train[test_idx, :, i] = y_test_pred
            
            logloss = evaluate(y_test, y_test_pred)
            avg_logloss += logloss
            # print ("  logloss: %f" % logloss)
            
            y_submission_pred = model.predict_proba(X_submission)           
            stack_test_model_i[:, :, j] = y_submission_pred
        
        avg_logloss = avg_logloss / n_folds
        print ("model average logloss: %f" % avg_logloss)
        summary[i] = avg_logloss
        
        stack_test[:, :, i] = stack_test_model_i.mean(axis=2)

    return np.swapaxes(stack_train, 1, 2).reshape((X.shape[0], -1)), np.swapaxes(stack_test, 1, 2).reshape((X_submission.shape[0], -1)), summary

# %%
def create_2_layer_keras_model(input_dim, output_dim,first,second,denn):
    model = Sequential()
    model.add(Dropout(denn, input_shape=(input_dim,)))
    model.add(Dense(first, use_bias=True,bias_initializer='glorot_normal', kernel_initializer='glorot_normal', activation='relu',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    model.add(Dropout(denn))
    model.add(Dense(second,use_bias=True,bias_initializer='glorot_normal',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_initializer='glorot_normal', activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    model.add(Dropout(denn))
    model.add(Dense(output_dim,use_bias=True,bias_initializer='glorot_normal',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_initializer='glorot_normal', activation='softmax', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy', 'categorical_crossentropy'])
    return model

def create_3_layer_keras_model(input_dim, output_dim,first,second,third,denn):
    model = Sequential()
    model.add(Dropout(0.05, input_shape=(input_dim,)))
    model.add(Dense(first, use_bias=True,bias_initializer='glorot_normal', kernel_initializer='glorot_normal', activation='relu',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    model.add(Dropout(denn))    
    model.add(Dense(second, use_bias=True,bias_initializer='glorot_normal',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_initializer='glorot_normal', activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    model.add(Dropout(denn))
    model.add(Dense(third, use_bias=True,bias_initializer='glorot_normal',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_initializer='glorot_normal', activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    model.add(Dropout(denn))
    model.add(Dense(output_dim,use_bias=True,bias_initializer='glorot_normal',bias_regularizer=l1_l2(l1=1e-5, l2=1e-5), kernel_initializer='glorot_normal', activation='softmax', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)))
    
    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy', 'categorical_crossentropy'])
    return model

# %%
# start_time = time.time()

logging.basicConfig(level=logging.DEBUG,
          format='[%(asctime)s]: %(message)s ',
          datefmt='%Y-%m-%d %H:%M:%S',
          stream=sys.stdout,
          filemode="w"
          )

# %%
logging.info('Load data')
train_df, test_df = load_data()
X, y, X_submission = process_data(train_df, test_df, transform='log')

# training phase 1
logging.info('Training phase 1')
models = []
# models += [MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes = (30, 10), random_state = 1, verbose = True)]
# models += [KerasClassifier(build_fn=create_2_layer_keras_model, input_dim=X.shape[1], output_dim=9, nb_epoch=200, batch_size=256, verbose=0)]
# models += [KerasClassifier(build_fn=create_3_layer_keras_model, input_dim=X.shape[1], output_dim=9, nb_epoch=200, batch_size=256, verbose=0)]

logging.info('List of models to train and ensemble:')
# Out:
# [2020-03-01 12:21:34]: Load data
# [2020-03-01 12:21:35]: NumExpr defaulting to 8 threads.
# [2020-03-01 12:21:35]: Training phase 1
# [2020-03-01 12:21:35]: List of models to train and ensemble:

# %%
# train_models_pred, test_models_pred, summary = models_Split_train(models, X, y, X_submission, n_classes=9, n_folds=5)
first_layer=[4096,2048,1024,526]
second_layer=[2048,1024,526,256]
third_layer=[1024,526,256,128]
dens_list=[0.05]
num=len(first_layer)
loss=np.zeros((num,num,num))
for i in range(num):
  for j in range(num):
    for k in range(num):
      models = [KerasClassifier(build_fn=create_3_layer_keras_model, input_dim=X.shape[1],output_dim=9,first=first_layer[i],second=second_layer[j],third=third_layer[k],denn=dens_list[0], nb_epoch=800, batch_size=256, verbose=0)]
      logloss=models_Split_train(models, X, y, X_submission, n_classes=9, n_folds=5)
      loss[i,j,k]=logloss
print(loss)
# Out:
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D188>
#   logloss: 0.562605
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D088>
#   logloss: 0.571882
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D188>
#   logloss: 0.553885
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D088>
#   logloss: 0.567148
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D188>
#   logloss: 0.567377
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D088>
#   logloss: 0.564832
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD0D188>
#   logloss: 0.560274
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.557548
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.553663
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.579783
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.573623
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.544667
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.569131
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.567177
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.559206
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.566254
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.586759
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.552703
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.572292
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.572108
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.561915
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.560522
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.565611
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002594AA710C8>
#   logloss: 0.552927
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259549BFA08>
#   logloss: 0.547561
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.545978
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.564001
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.555172
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.551501
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.543421
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.559946
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.548963
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.548885
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.560719
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.553136
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.582570
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.551333
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.570306
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.553288
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.559163
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.546350
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.541925
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259920BABC8>
#   logloss: 0.541572
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002599DF9ED88>
#   logloss: 0.554392
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.560819
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.554600
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.549702
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.561349
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.555329
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.557253
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.561256
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.562970
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.542292
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.560668
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.553764
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.567126
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.561546
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.549364
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.553248
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.550891
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.553254
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.553115
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C974C08>
#   logloss: 0.560319
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596C9A3E88>
#   logloss: 0.565274
# [[[0.56260483 0.5718819  0.55388488 0.5671485 ]
#   [0.56737735 0.56483222 0.56027395 0.55754804]
#   [0.55366291 0.5797827  0.57362291 0.54466676]
#   [0.56913086 0.56717732 0.55920565 0.5662537 ]]
#
#  [[0.58675857 0.55270258 0.57229204 0.57210781]
#   [0.56191466 0.56052195 0.56561122 0.55292683]
#   [0.54756054 0.5459777  0.56400081 0.55517198]
#   [0.55150094 0.54342078 0.55994569 0.54896283]]
#
#  [[0.54888502 0.56071894 0.55313607 0.5825699 ]
#   [0.55133253 0.57030621 0.55328829 0.55916253]
#   [0.54634968 0.54192492 0.54157233 0.55439248]
#   [0.56081855 0.55459982 0.54970238 0.56134932]]
#
#  [[0.55532866 0.55725308 0.56125648 0.56296997]
#   [0.54229168 0.5606682  0.5537641  0.56712598]
#   [0.56154597 0.54936354 0.55324755 0.55089109]
#   [0.55325406 0.55311505 0.56031935 0.56527396]]]

# %%
np.where(loss==np.min(loss))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-173107c098c9> in <module>
# ----> 1 np.where(loss==np.min(loss))
#
# NameError: name 'loss' is not defined

# %%
# training phase 1
logging.info('Training phase 1')
models = []
train_models_pred_list=[]
test_models_pred_list=[]
for i in range(120):
  epoch=500+i*10
  models = [KerasClassifier(build_fn=create_3_layer_keras_model, input_dim=X.shape[1],output_dim=9,first=1024,second=512,third=256,denn=0.05, nb_epoch=epoch, batch_size=256, verbose=0)]
  train_models_pred, test_models_pred, summary = models_CV_train(models, X, y, X_submission, n_classes=9, n_folds=5)
  train_models_pred_list.append(train_models_pred)
  test_models_pred_list.append(test_models_pred)
# Out:
# [2020-02-29 16:07:14]: Training phase 1
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD54B08>
#   Fold 0
#   logloss: 0.557680
#   Fold 1
#   logloss: 0.568144
#   Fold 2
#   logloss: 0.569654
#   Fold 3
#   logloss: 0.580111
#   Fold 4
#   logloss: 0.564145
# model average logloss: 0.567947
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259A4936F48>
#   Fold 0
#   logloss: 0.566772
#   Fold 1
#   logloss: 0.558566
#   Fold 2
#   logloss: 0.584645
#   Fold 3
#   logloss: 0.568973
#   Fold 4
#   logloss: 0.563456
# model average logloss: 0.568482
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000258ECD54B08>
#   Fold 0
#   logloss: 0.583106
#   Fold 1
#   logloss: 0.557151
#   Fold 2
#   logloss: 0.568221
#   Fold 3
#   logloss: 0.557760
#   Fold 4
#   logloss: 0.568083
# model average logloss: 0.566864
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x00000259A4936F48>
#   Fold 0
#   logloss: 0.569861
#   Fold 1
#   logloss: 0.562197
#   Fold 2
#   logloss: 0.560008
#   Fold 3
#   logloss: 0.570346
#   Fold 4
#   logloss: 0.569465
# model average logloss: 0.566375
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.568823
#   Fold 1
#   logloss: 0.568295
#   Fold 2
#   logloss: 0.576458
#   Fold 3
#   logloss: 0.572269
#   Fold 4
#   logloss: 0.558396
# model average logloss: 0.568848
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966C77D08>
#   Fold 0
#   logloss: 0.564155
#   Fold 1
#   logloss: 0.568031
#   Fold 2
#   logloss: 0.572173
#   Fold 3
#   logloss: 0.565233
#   Fold 4
#   logloss: 0.578044
# model average logloss: 0.569527
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.565587
#   Fold 1
#   logloss: 0.557241
#   Fold 2
#   logloss: 0.559478
#   Fold 3
#   logloss: 0.557792
#   Fold 4
#   logloss: 0.560766
# model average logloss: 0.560173
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966C77D08>
#   Fold 0
#   logloss: 0.557892
#   Fold 1
#   logloss: 0.580368
#   Fold 2
#   logloss: 0.562667
#   Fold 3
#   logloss: 0.587054
#   Fold 4
#   logloss: 0.562440
# model average logloss: 0.570084
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.564256
#   Fold 1
#   logloss: 0.555777
#   Fold 2
#   logloss: 0.576519
#   Fold 3
#   logloss: 0.569996
#   Fold 4
#   logloss: 0.555692
# model average logloss: 0.564448
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.570035
#   Fold 1
#   logloss: 0.567741
#   Fold 2
#   logloss: 0.569203
#   Fold 3
#   logloss: 0.571916
#   Fold 4
#   logloss: 0.577747
# model average logloss: 0.571328
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.582600
#   Fold 1
#   logloss: 0.553099
#   Fold 2
#   logloss: 0.573102
#   Fold 3
#   logloss: 0.592630
#   Fold 4
#   logloss: 0.564607
# model average logloss: 0.573208
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.579612
#   Fold 1
#   logloss: 0.552767
#   Fold 2
#   logloss: 0.578907
#   Fold 3
#   logloss: 0.564322
#   Fold 4
#   logloss: 0.570216
# model average logloss: 0.569165
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.569796
#   Fold 1
#   logloss: 0.563643
#   Fold 2
#   logloss: 0.559602
#   Fold 3
#   logloss: 0.587523
#   Fold 4
#   logloss: 0.557124
# model average logloss: 0.567538
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.564868
#   Fold 1
#   logloss: 0.557739
#   Fold 2
#   logloss: 0.570985
#   Fold 3
#   logloss: 0.563147
#   Fold 4
#   logloss: 0.558582
# model average logloss: 0.563064
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.562066
#   Fold 1
#   logloss: 0.563022
#   Fold 2
#   logloss: 0.564455
#   Fold 3
#   logloss: 0.595978
#   Fold 4
#   logloss: 0.580692
# model average logloss: 0.573242
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.572368
#   Fold 1
#   logloss: 0.556556
#   Fold 2
#   logloss: 0.567787
#   Fold 3
#   logloss: 0.569424
#   Fold 4
#   logloss: 0.557056
# model average logloss: 0.564638
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.572501
#   Fold 1
#   logloss: 0.556993
#   Fold 2
#   logloss: 0.560108
#   Fold 3
#   logloss: 0.563269
#   Fold 4
#   logloss: 0.552131
# model average logloss: 0.561000
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563994
#   Fold 1
#   logloss: 0.563992
#   Fold 2
#   logloss: 0.569473
#   Fold 3
#   logloss: 0.567442
#   Fold 4
#   logloss: 0.560827
# model average logloss: 0.565146
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.567524
#   Fold 1
#   logloss: 0.557309
#   Fold 2
#   logloss: 0.558338
#   Fold 3
#   logloss: 0.561397
#   Fold 4
#   logloss: 0.566121
# model average logloss: 0.562138
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.560116
#   Fold 1
#   logloss: 0.573131
#   Fold 2
#   logloss: 0.570720
#   Fold 3
#   logloss: 0.565844
#   Fold 4
#   logloss: 0.566352
# model average logloss: 0.567233
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.576985
#   Fold 1
#   logloss: 0.564144
#   Fold 2
#   logloss: 0.581152
#   Fold 3
#   logloss: 0.562671
#   Fold 4
#   logloss: 0.574086
# model average logloss: 0.571808
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.560332
#   Fold 1
#   logloss: 0.575114
#   Fold 2
#   logloss: 0.562815
#   Fold 3
#   logloss: 0.589570
#   Fold 4
#   logloss: 0.574592
# model average logloss: 0.572485
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.563656
#   Fold 1
#   logloss: 0.566489
#   Fold 2
#   logloss: 0.567400
#   Fold 3
#   logloss: 0.570223
#   Fold 4
#   logloss: 0.561923
# model average logloss: 0.565938
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.572105
#   Fold 1
#   logloss: 0.557770
#   Fold 2
#   logloss: 0.564871
#   Fold 3
#   logloss: 0.567765
#   Fold 4
#   logloss: 0.567269
# model average logloss: 0.565956
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.575018
#   Fold 1
#   logloss: 0.565624
#   Fold 2
#   logloss: 0.564411
#   Fold 3
#   logloss: 0.577814
#   Fold 4
#   logloss: 0.562351
# model average logloss: 0.569044
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.569756
#   Fold 1
#   logloss: 0.562994
#   Fold 2
#   logloss: 0.574104
#   Fold 3
#   logloss: 0.573042
#   Fold 4
#   logloss: 0.568176
# model average logloss: 0.569614
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.564733
#   Fold 1
#   logloss: 0.554472
#   Fold 2
#   logloss: 0.556797
#   Fold 3
#   logloss: 0.563996
#   Fold 4
#   logloss: 0.563154
# model average logloss: 0.560630
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.576471
#   Fold 1
#   logloss: 0.557568
#   Fold 2
#   logloss: 0.573903
#   Fold 3
#   logloss: 0.579951
#   Fold 4
#   logloss: 0.568334
# model average logloss: 0.571245
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.585267
#   Fold 1
#   logloss: 0.554739
#   Fold 2
#   logloss: 0.570057
#   Fold 3
#   logloss: 0.585909
#   Fold 4
#   logloss: 0.565834
# model average logloss: 0.572361
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563657
#   Fold 1
#   logloss: 0.554663
#   Fold 2
#   logloss: 0.565988
#   Fold 3
#   logloss: 0.568896
#   Fold 4
#   logloss: 0.588261
# model average logloss: 0.568293
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.577594
#   Fold 1
#   logloss: 0.566771
#   Fold 2
#   logloss: 0.573412
#   Fold 3
#   logloss: 0.573340
#   Fold 4
#   logloss: 0.563505
# model average logloss: 0.570925
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.560576
#   Fold 1
#   logloss: 0.560144
#   Fold 2
#   logloss: 0.580566
#   Fold 3
#   logloss: 0.564294
#   Fold 4
#   logloss: 0.577760
# model average logloss: 0.568668
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.566010
#   Fold 1
#   logloss: 0.566151
#   Fold 2
#   logloss: 0.579203
#   Fold 3
#   logloss: 0.563697
#   Fold 4
#   logloss: 0.572527
# model average logloss: 0.569517
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.575839
#   Fold 1
#   logloss: 0.567181
#   Fold 2
#   logloss: 0.559411
#   Fold 3
#   logloss: 0.566474
#   Fold 4
#   logloss: 0.552676
# model average logloss: 0.564316
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.575629
#   Fold 1
#   logloss: 0.556491
#   Fold 2
#   logloss: 0.562828
#   Fold 3
#   logloss: 0.570690
#   Fold 4
#   logloss: 0.575939
# model average logloss: 0.568315
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.572399
#   Fold 1
#   logloss: 0.572606
#   Fold 2
#   logloss: 0.567135
#   Fold 3
#   logloss: 0.556185
#   Fold 4
#   logloss: 0.575236
# model average logloss: 0.568712
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.566759
#   Fold 1
#   logloss: 0.553015
#   Fold 2
#   logloss: 0.560470
#   Fold 3
#   logloss: 0.564512
#   Fold 4
#   logloss: 0.571576
# model average logloss: 0.563266
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.574964
#   Fold 1
#   logloss: 0.570813
#   Fold 2
#   logloss: 0.567141
#   Fold 3
#   logloss: 0.561292
#   Fold 4
#   logloss: 0.569227
# model average logloss: 0.568688
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.588363
#   Fold 1
#   logloss: 0.559325
#   Fold 2
#   logloss: 0.566708
#   Fold 3
#   logloss: 0.580003
#   Fold 4
#   logloss: 0.587757
# model average logloss: 0.576431
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.566199
#   Fold 1
#   logloss: 0.553854
#   Fold 2
#   logloss: 0.576520
#   Fold 3
#   logloss: 0.568563
#   Fold 4
#   logloss: 0.579473
# model average logloss: 0.568922
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.569843
#   Fold 1
#   logloss: 0.554900
#   Fold 2
#   logloss: 0.584843
#   Fold 3
#   logloss: 0.568647
#   Fold 4
#   logloss: 0.560591
# model average logloss: 0.567765
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.578061
#   Fold 1
#   logloss: 0.558634
#   Fold 2
#   logloss: 0.579971
#   Fold 3
#   logloss: 0.568861
#   Fold 4
#   logloss: 0.552246
# model average logloss: 0.567555
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.566130
#   Fold 1
#   logloss: 0.566431
#   Fold 2
#   logloss: 0.569908
#   Fold 3
#   logloss: 0.570991
#   Fold 4
#   logloss: 0.573251
# model average logloss: 0.569342
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563001
#   Fold 1
#   logloss: 0.552945
#   Fold 2
#   logloss: 0.569603
#   Fold 3
#   logloss: 0.566945
#   Fold 4
#   logloss: 0.561144
# model average logloss: 0.562727
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.579682
#   Fold 1
#   logloss: 0.566477
#   Fold 2
#   logloss: 0.562763
#   Fold 3
#   logloss: 0.570132
#   Fold 4
#   logloss: 0.560519
# model average logloss: 0.567915
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.569127
#   Fold 1
#   logloss: 0.565668
#   Fold 2
#   logloss: 0.560945
#   Fold 3
#   logloss: 0.575774
#   Fold 4
#   logloss: 0.572829
# model average logloss: 0.568869
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.578696
#   Fold 1
#   logloss: 0.560774
#   Fold 2
#   logloss: 0.578907
#   Fold 3
#   logloss: 0.559172
#   Fold 4
#   logloss: 0.586966
# model average logloss: 0.572903
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.559476
#   Fold 1
#   logloss: 0.564828
#   Fold 2
#   logloss: 0.572895
#   Fold 3
#   logloss: 0.559015
#   Fold 4
#   logloss: 0.579187
# model average logloss: 0.567080
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.574265
#   Fold 1
#   logloss: 0.564281
#   Fold 2
#   logloss: 0.572723
#   Fold 3
#   logloss: 0.567845
#   Fold 4
#   logloss: 0.568429
# model average logloss: 0.569509
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.573807
#   Fold 1
#   logloss: 0.552520
#   Fold 2
#   logloss: 0.565469
#   Fold 3
#   logloss: 0.572277
#   Fold 4
#   logloss: 0.564422
# model average logloss: 0.565699
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.560182
#   Fold 1
#   logloss: 0.571608
#   Fold 2
#   logloss: 0.573513
#   Fold 3
#   logloss: 0.571183
#   Fold 4
#   logloss: 0.561599
# model average logloss: 0.567617
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.569136
#   Fold 1
#   logloss: 0.552432
#   Fold 2
#   logloss: 0.566144
#   Fold 3
#   logloss: 0.574789
#   Fold 4
#   logloss: 0.562410
# model average logloss: 0.564982
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.568301
#   Fold 1
#   logloss: 0.564360
#   Fold 2
#   logloss: 0.560323
#   Fold 3
#   logloss: 0.576555
#   Fold 4
#   logloss: 0.579795
# model average logloss: 0.569867
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.584260
#   Fold 1
#   logloss: 0.561187
#   Fold 2
#   logloss: 0.559939
#   Fold 3
#   logloss: 0.560051
#   Fold 4
#   logloss: 0.565535
# model average logloss: 0.566194
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.564271
#   Fold 1
#   logloss: 0.555675
#   Fold 2
#   logloss: 0.572388
#   Fold 3
#   logloss: 0.576720
#   Fold 4
#   logloss: 0.575082
# model average logloss: 0.568827
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563839
#   Fold 1
#   logloss: 0.555743
#   Fold 2
#   logloss: 0.558147
#   Fold 3
#   logloss: 0.565439
#   Fold 4
#   logloss: 0.568706
# model average logloss: 0.562375
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.580566
#   Fold 1
#   logloss: 0.560122
#   Fold 2
#   logloss: 0.572469
#   Fold 3
#   logloss: 0.564789
#   Fold 4
#   logloss: 0.569796
# model average logloss: 0.569548
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.581522
#   Fold 1
#   logloss: 0.562882
#   Fold 2
#   logloss: 0.568714
#   Fold 3
#   logloss: 0.572695
#   Fold 4
#   logloss: 0.556558
# model average logloss: 0.568474
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.574609
#   Fold 1
#   logloss: 0.562037
#   Fold 2
#   logloss: 0.562024
#   Fold 3
#   logloss: 0.573206
#   Fold 4
#   logloss: 0.559467
# model average logloss: 0.566269
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563648
#   Fold 1
#   logloss: 0.567609
#   Fold 2
#   logloss: 0.576098
#   Fold 3
#   logloss: 0.568322
#   Fold 4
#   logloss: 0.566375
# model average logloss: 0.568410
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.560494
#   Fold 1
#   logloss: 0.567828
#   Fold 2
#   logloss: 0.563196
#   Fold 3
#   logloss: 0.558339
#   Fold 4
#   logloss: 0.561187
# model average logloss: 0.562209
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.559761
#   Fold 1
#   logloss: 0.557305
#   Fold 2
#   logloss: 0.561512
#   Fold 3
#   logloss: 0.572071
#   Fold 4
#   logloss: 0.562337
# model average logloss: 0.562597
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.570871
#   Fold 1
#   logloss: 0.550000
#   Fold 2
#   logloss: 0.574085
#   Fold 3
#   logloss: 0.569522
#   Fold 4
#   logloss: 0.556156
# model average logloss: 0.564127
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.571200
#   Fold 1
#   logloss: 0.551617
#   Fold 2
#   logloss: 0.592664
#   Fold 3
#   logloss: 0.570177
#   Fold 4
#   logloss: 0.566442
# model average logloss: 0.570420
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.556679
#   Fold 1
#   logloss: 0.560219
#   Fold 2
#   logloss: 0.558806
#   Fold 3
#   logloss: 0.574756
#   Fold 4
#   logloss: 0.560758
# model average logloss: 0.562244
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.576450
#   Fold 1
#   logloss: 0.589197
#   Fold 2
#   logloss: 0.576332
#   Fold 3
#   logloss: 0.575084
#   Fold 4
#   logloss: 0.565778
# model average logloss: 0.576568
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.560590
#   Fold 1
#   logloss: 0.555418
#   Fold 2
#   logloss: 0.569686
#   Fold 3
#   logloss: 0.566735
#   Fold 4
#   logloss: 0.575552
# model average logloss: 0.565596
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.577180
#   Fold 1
#   logloss: 0.556088
#   Fold 2
#   logloss: 0.561739
#   Fold 3
#   logloss: 0.569599
#   Fold 4
#   logloss: 0.562779
# model average logloss: 0.565477
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.570757
#   Fold 1
#   logloss: 0.565838
#   Fold 2
#   logloss: 0.557867
#   Fold 3
#   logloss: 0.570582
#   Fold 4
#   logloss: 0.561602
# model average logloss: 0.565329
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.573362
#   Fold 1
#   logloss: 0.554025
#   Fold 2
#   logloss: 0.569267
#   Fold 3
#   logloss: 0.568874
#   Fold 4
#   logloss: 0.567409
# model average logloss: 0.566587
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.563223
#   Fold 1
#   logloss: 0.558506
#   Fold 2
#   logloss: 0.569340
#   Fold 3
#   logloss: 0.567987
#   Fold 4
#   logloss: 0.568994
# model average logloss: 0.565610
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.566815
#   Fold 1
#   logloss: 0.554774
#   Fold 2
#   logloss: 0.585249
#   Fold 3
#   logloss: 0.566120
#   Fold 4
#   logloss: 0.569535
# model average logloss: 0.568499
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.574974
#   Fold 1
#   logloss: 0.553512
#   Fold 2
#   logloss: 0.558815
#   Fold 3
#   logloss: 0.572015
#   Fold 4
#   logloss: 0.560585
# model average logloss: 0.563980
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.575462
#   Fold 1
#   logloss: 0.555062
#   Fold 2
#   logloss: 0.558414
#   Fold 3
#   logloss: 0.569685
#   Fold 4
#   logloss: 0.571229
# model average logloss: 0.565970
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.563574
#   Fold 1
#   logloss: 0.557497
#   Fold 2
#   logloss: 0.591274
#   Fold 3
#   logloss: 0.574219
#   Fold 4
#   logloss: 0.566658
# model average logloss: 0.570644
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.570524
#   Fold 1
#   logloss: 0.566378
#   Fold 2
#   logloss: 0.572319
#   Fold 3
#   logloss: 0.558522
#   Fold 4
#   logloss: 0.564828
# model average logloss: 0.566514
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.592103
#   Fold 1
#   logloss: 0.551628
#   Fold 2
#   logloss: 0.569275
#   Fold 3
#   logloss: 0.573742
#   Fold 4
#   logloss: 0.566765
# model average logloss: 0.570703
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.574802
#   Fold 1
#   logloss: 0.553932
#   Fold 2
#   logloss: 0.569263
#   Fold 3
#   logloss: 0.566382
#   Fold 4
#   logloss: 0.558467
# model average logloss: 0.564569
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.569873
#   Fold 1
#   logloss: 0.552914
#   Fold 2
#   logloss: 0.580542
#   Fold 3
#   logloss: 0.554998
#   Fold 4
#   logloss: 0.582267
# model average logloss: 0.568119
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.565315
#   Fold 1
#   logloss: 0.555109
#   Fold 2
#   logloss: 0.579406
#   Fold 3
#   logloss: 0.571510
#   Fold 4
#   logloss: 0.561259
# model average logloss: 0.566520
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.574997
#   Fold 1
#   logloss: 0.561287
#   Fold 2
#   logloss: 0.566290
#   Fold 3
#   logloss: 0.564783
#   Fold 4
#   logloss: 0.565671
# model average logloss: 0.566606
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.564615
#   Fold 1
#   logloss: 0.549743
#   Fold 2
#   logloss: 0.561918
#   Fold 3
#   logloss: 0.575173
#   Fold 4
#   logloss: 0.560723
# model average logloss: 0.562434
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.572486
#   Fold 1
#   logloss: 0.553151
#   Fold 2
#   logloss: 0.562822
#   Fold 3
#   logloss: 0.558259
#   Fold 4
#   logloss: 0.570275
# model average logloss: 0.563399
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.588487
#   Fold 1
#   logloss: 0.550040
#   Fold 2
#   logloss: 0.568939
#   Fold 3
#   logloss: 0.577307
#   Fold 4
#   logloss: 0.578202
# model average logloss: 0.572595
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.557153
#   Fold 1
#   logloss: 0.558376
#   Fold 2
#   logloss: 0.565929
#   Fold 3
#   logloss: 0.573168
#   Fold 4
#   logloss: 0.557841
# model average logloss: 0.562493
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.593039
#   Fold 1
#   logloss: 0.564124
#   Fold 2
#   logloss: 0.559624
#   Fold 3
#   logloss: 0.565244
#   Fold 4
#   logloss: 0.569330
# model average logloss: 0.570272
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.563510
#   Fold 1
#   logloss: 0.563469
#   Fold 2
#   logloss: 0.563955
#   Fold 3
#   logloss: 0.582580
#   Fold 4
#   logloss: 0.568281
# model average logloss: 0.568359
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.589076
#   Fold 1
#   logloss: 0.549433
#   Fold 2
#   logloss: 0.573697
#   Fold 3
#   logloss: 0.565092
#   Fold 4
#   logloss: 0.563881
# model average logloss: 0.568236
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.562151
#   Fold 1
#   logloss: 0.552079
#   Fold 2
#   logloss: 0.584948
#   Fold 3
#   logloss: 0.568146
#   Fold 4
#   logloss: 0.593702
# model average logloss: 0.572205
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.564223
#   Fold 1
#   logloss: 0.561851
#   Fold 2
#   logloss: 0.570240
#   Fold 3
#   logloss: 0.577087
#   Fold 4
#   logloss: 0.576536
# model average logloss: 0.569988
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.561754
#   Fold 1
#   logloss: 0.566249
#   Fold 2
#   logloss: 0.571845
#   Fold 3
#   logloss: 0.571947
#   Fold 4
#   logloss: 0.569829
# model average logloss: 0.568325
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.559519
#   Fold 1
#   logloss: 0.564705
#   Fold 2
#   logloss: 0.572390
#   Fold 3
#   logloss: 0.577005
#   Fold 4
#   logloss: 0.568845
# model average logloss: 0.568493
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.558203
#   Fold 1
#   logloss: 0.554119
#   Fold 2
#   logloss: 0.559692
#   Fold 3
#   logloss: 0.567670
#   Fold 4
#   logloss: 0.563015
# model average logloss: 0.560540
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.586008
#   Fold 1
#   logloss: 0.551189
#   Fold 2
#   logloss: 0.568052
#   Fold 3
#   logloss: 0.567764
#   Fold 4
#   logloss: 0.567513
# model average logloss: 0.568105
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.577749
#   Fold 1
#   logloss: 0.554314
#   Fold 2
#   logloss: 0.579241
#   Fold 3
#   logloss: 0.575175
#   Fold 4
#   logloss: 0.566974
# model average logloss: 0.570691
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.561901
#   Fold 1
#   logloss: 0.554530
#   Fold 2
#   logloss: 0.569775
#   Fold 3
#   logloss: 0.568055
#   Fold 4
#   logloss: 0.569716
# model average logloss: 0.564795
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.571456
#   Fold 1
#   logloss: 0.557775
#   Fold 2
#   logloss: 0.570300
#   Fold 3
#   logloss: 0.570978
#   Fold 4
#   logloss: 0.597508
# model average logloss: 0.573604
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.580599
#   Fold 1
#   logloss: 0.563781
#   Fold 2
#   logloss: 0.571170
#   Fold 3
#   logloss: 0.565095
#   Fold 4
#   logloss: 0.559908
# model average logloss: 0.568111
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.565434
#   Fold 1
#   logloss: 0.557820
#   Fold 2
#   logloss: 0.572471
#   Fold 3
#   logloss: 0.572710
#   Fold 4
#   logloss: 0.564449
# model average logloss: 0.566577
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.566134
#   Fold 1
#   logloss: 0.548062
#   Fold 2
#   logloss: 0.562753
#   Fold 3
#   logloss: 0.566105
#   Fold 4
#   logloss: 0.569835
# model average logloss: 0.562578
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.564373
#   Fold 1
#   logloss: 0.558340
#   Fold 2
#   logloss: 0.563018
#   Fold 3
#   logloss: 0.573757
#   Fold 4
#   logloss: 0.575920
# model average logloss: 0.567082
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.570735
#   Fold 1
#   logloss: 0.560661
#   Fold 2
#   logloss: 0.575497
#   Fold 3
#   logloss: 0.579053
#   Fold 4
#   logloss: 0.563385
# model average logloss: 0.569866
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.582632
#   Fold 1
#   logloss: 0.553153
#   Fold 2
#   logloss: 0.580042
#   Fold 3
#   logloss: 0.574667
#   Fold 4
#   logloss: 0.558150
# model average logloss: 0.569729
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.563243
#   Fold 1
#   logloss: 0.570553
#   Fold 2
#   logloss: 0.565407
#   Fold 3
#   logloss: 0.556824
#   Fold 4
#   logloss: 0.567276
# model average logloss: 0.564661
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.563606
#   Fold 1
#   logloss: 0.570990
#   Fold 2
#   logloss: 0.569277
#   Fold 3
#   logloss: 0.565731
#   Fold 4
#   logloss: 0.584268
# model average logloss: 0.570774
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.562103
#   Fold 1
#   logloss: 0.556931
#   Fold 2
#   logloss: 0.573634
#   Fold 3
#   logloss: 0.565906
#   Fold 4
#   logloss: 0.574557
# model average logloss: 0.566626
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.566760
#   Fold 1
#   logloss: 0.574218
#   Fold 2
#   logloss: 0.559607
#   Fold 3
#   logloss: 0.558609
#   Fold 4
#   logloss: 0.561977
# model average logloss: 0.564234
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.561856
#   Fold 1
#   logloss: 0.568485
#   Fold 2
#   logloss: 0.562766
#   Fold 3
#   logloss: 0.582628
#   Fold 4
#   logloss: 0.576454
# model average logloss: 0.570438
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.573540
#   Fold 1
#   logloss: 0.562212
#   Fold 2
#   logloss: 0.569725
#   Fold 3
#   logloss: 0.565452
#   Fold 4
#   logloss: 0.558669
# model average logloss: 0.565920
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.585691
#   Fold 1
#   logloss: 0.565098
#   Fold 2
#   logloss: 0.561487
#   Fold 3
#   logloss: 0.569228
#   Fold 4
#   logloss: 0.561215
# model average logloss: 0.568544
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.572516
#   Fold 1
#   logloss: 0.566448
#   Fold 2
#   logloss: 0.571557
#   Fold 3
#   logloss: 0.565437
#   Fold 4
#   logloss: 0.573602
# model average logloss: 0.569912
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.579026
#   Fold 1
#   logloss: 0.555380
#   Fold 2
#   logloss: 0.559214
#   Fold 3
#   logloss: 0.561408
#   Fold 4
#   logloss: 0.562041
# model average logloss: 0.563413
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.573609
#   Fold 1
#   logloss: 0.560107
#   Fold 2
#   logloss: 0.574220
#   Fold 3
#   logloss: 0.570402
#   Fold 4
#   logloss: 0.553209
# model average logloss: 0.566309
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.564409
#   Fold 1
#   logloss: 0.554842
#   Fold 2
#   logloss: 0.561769
#   Fold 3
#   logloss: 0.581449
#   Fold 4
#   logloss: 0.560316
# model average logloss: 0.564557
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.558486
#   Fold 1
#   logloss: 0.556552
#   Fold 2
#   logloss: 0.567642
#   Fold 3
#   logloss: 0.568030
#   Fold 4
#   logloss: 0.569903
# model average logloss: 0.564123
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.555651
#   Fold 1
#   logloss: 0.565978
#   Fold 2
#   logloss: 0.571767
#   Fold 3
#   logloss: 0.577760
#   Fold 4
#   logloss: 0.561568
# model average logloss: 0.566545
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.572236
#   Fold 1
#   logloss: 0.558717
#   Fold 2
#   logloss: 0.575781
#   Fold 3
#   logloss: 0.558189
#   Fold 4
#   logloss: 0.571876
# model average logloss: 0.567360
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.572559
#   Fold 1
#   logloss: 0.556361
#   Fold 2
#   logloss: 0.580596
#   Fold 3
#   logloss: 0.570962
#   Fold 4
#   logloss: 0.556007
# model average logloss: 0.567297
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x000002596EC4EF88>
#   Fold 0
#   logloss: 0.588125
#   Fold 1
#   logloss: 0.572923
#   Fold 2
#   logloss: 0.564711
#   Fold 3
#   logloss: 0.567497
#   Fold 4
#   logloss: 0.575449
# model average logloss: 0.573741
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000025966421EC8>
#   Fold 0
#   logloss: 0.574003
#   Fold 1
#   logloss: 0.570138
#   Fold 2
#   logloss: 0.568883
#   Fold 3
#   logloss: 0.561017
#   Fold 4
#   logloss: 0.566572
# model average logloss: 0.568123

# %%
# training phase 1
logging.info('Training phase 2')
models = []
train_models_pred_list_2=[]
test_models_pred_list_2=[]
for i in range(120):
  epoch=300+i*10
  models = [KerasClassifier(build_fn=create_2_layer_keras_model, input_dim=X.shape[1],output_dim=9,first=4096,second=526,denn=0.05, nb_epoch=epoch, batch_size=256, verbose=0)]
  train_models_pred, test_models_pred, summary = models_CV_train(models, X, y, X_submission, n_classes=9, n_folds=5)
  train_models_pred_list_2.append(train_models_pred)
  test_models_pred_list_2.append(test_models_pred)
# Out:
# [2020-03-01 12:22:11]: Training phase 2
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565820
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9EA6588>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561925
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.571598
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9EA6588>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.570243
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.560145
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82B08B48>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.569367
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561017
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82B08B48>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.569681
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.570248
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.574794
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.571448
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565546
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.559532
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565676
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.574359
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565735
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564357
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.567135
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.570331
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.560025
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.563511
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.562384
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.574116
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565744
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.560920
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.569179
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564136
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.562161
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.568407
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564450
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.558915
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.572337
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.562476
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.574001
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564450
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.560863
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.567049
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.566785
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561588
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561683
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.563673
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565190
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.568199
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.560260
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565242
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.568239
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.572836
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.563926
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.566060
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561885
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564473
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561702
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565096
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.571299
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565540
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564075
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561210
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.570553
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.564844
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.562484
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.565994
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.570775
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022BB9F306C8>
#   Fold 0
#   Fold 1
#   Fold 2
#   Fold 3
#   Fold 4
# model average logloss: 0.561147
# Model 0: <keras.wrappers.scikit_learn.KerasClassifier object at 0x0000022B82AF0508>
#   Fold 0
#   Fold 1
#   Fold 2

# %%
train_models_pred_final=np.zeros((61878,9))
for i in range(len(train_models_pred_list)):
  train_models_pred_final=train_models_pred_final+train_models_pred_list[i]
  logloss_1 = evaluate(y,train_models_pred_final/(i+1))
print(logloss_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a4013cb27ed> in <module>
# ----> 1 train_models_pred_final=np.zeros((61878,9))
#       2 for i in range(len(train_models_pred_list)):
#       3   train_models_pred_final=train_models_pred_final+train_models_pred_list[i]
#       4   logloss_1 = evaluate(y,train_models_pred_final/(i+1))
#       5 print(logloss_1)
#
# NameError: name 'np' is not defined

# %%
train_models_pred_final_2=np.zeros((61878,9))
for i in train_models_pred_list_2:
  train_models_pred_final_2=train_models_pred_final_2+i
logloss_2 = evaluate(y,train_models_pred_final_2/len(train_models_pred_list_2))
print(logloss_2)
# Out:
# 0.5338584489978203

# %%
train_models_pred_final=np.zeros((61878,9))
test_models_pred_final=np.zeros((144368,9))
for i in range(len(train_models_pred_list)):
  train_models_pred_final = train_models_pred_final + train_models_pred_list[i]
  test_models_pred_final = test_models_pred_final + test_models_pred_list[i]
  logloss_2 = evaluate(y,train_models_pred_final/len(train_models_pred_list))
print(logloss_2)
# Out:
# 0.5377954185558323

# %%
train_models_pred_final=train_models_pred_final/len(train_models_pred_list)
test_models_pred_final=test_models_pred_final/len(test_models_pred_list)
columns = ['Class_' + str(i + 1) for i in range(9)]
submission_df = pd.DataFrame(test_models_pred_final, columns=columns)
submission_df.index = submission_df.index + 1
# submission_df.to_csv('NN_2_12run.csv', sep=',',index_label='id')
np.savetxt("model20_test.csv", test_models_pred_final, delimiter=",")
np.savetxt("model20_train.csv", train_models_pred_final, delimiter=",")
